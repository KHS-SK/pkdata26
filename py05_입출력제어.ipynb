# %% [markdown]
# # 입출력 제어

# %% [markdown]
# ## 파일 생성 및 추가하기

# %%
# !pwd
# Out:
# /home/khs/data

# %%
f = open("새파일이에요.txt", "w")

f.close()

# %% [markdown]
# <table style="float:left">
# <thead>
# <tr>
# <th>파일열기모드</th>
# <th>설명</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>r</td>
# <td>읽기 모드: 파일을 읽기만 할 때 사용한다.</td>
# </tr>
# <tr>
# <td>w</td>
# <td>쓰기 모드: 파일에 내용을 쓸 때 사용한다.</td>
# </tr>
# <tr>
# <td>a</td>
# <td>추가 모드: 파일의 마지막에 새로운 내용을 추가할 때 사용한다.</td>
# </tr>
# </tbody>
# </table>

# %%
# 리눅스에서

f = open("/home/khs/test.txt", "w")

f.close()

# %%
f = open("새파일이에요.txt", "w")

for i in range(0, 20, 2):
    f.write(str(i) + "\n")

f.close()

# %%
import requests as req

f = open("즐겨찾기 종목.txt", "a")

url = "https://finance.naver.com/sise/sise_market_sum.naver"
ori = req.get(url).text

code = ['005930', '000270', '005380', '012450', '068270']

def finance(code = '005930'):

    start_title = ori.find(f'<a href="/item/main.naver?code={code}" class="tltle">')
    ori1 = ori[start_title : start_title + 70].replace(f'<a href="/item/main.naver?code={code}" class="tltle">','').replace('</a></td>', '').replace('</a></td', '').replace('\n', '').strip()
    ori2 = ori[start_title + 70 : start_title + 105].replace('<td class="number">', '').replace('</td>', '').replace('>', '').strip()
    print("종목:", ori1)
    print("가격:", ori2)

    result = "종목:" + ori1 + "\n" + "가격:" + ori2 + "\n"

    f.write(result)

for x in code:
    finance(x)

f.close()
# Out:
# 종목: 삼성전자
# 가격: 178,400
# 종목: 기아
# 가격: 164,700
# 종목: 현대차
# 가격: 504,000
# 종목: 한화에어로스페이스
# 가격: 1,127,000
# 종목: 셀트리온
# 가격: 238,500

# %% [markdown]
# ## 파일 읽기

# %%
# readline 함수 이용하기

# %%
# 응용 2

# 응용2

import requests as req
url = "https://api4.binance.com/api/v3/ticker/price?symbol=BTCUSDT"
res = req.get(url).text
print(res)
btc = res[29:34]
print(str(int(btc) * 1450) + '원') # 1억 1389만 6050원
won = str(int(btc) * 1450)

print(won)
# print(won[:1] +'억 ' + won[1:5] + '만 ' + won[5:] + '원')
print(((won[-12:8] +'억 ') if won[-12:-8] else "") + won[-8:-4] + '만 ' + won[-4:] + '원')
# Out:
# {"symbol":"BTCUSDT","price":"67185.42000000"}
# 97418250원
# 97418250
# 9741만 8250원

# %% [markdown]
# # 파이썬의 파일 쓰기 기능을 이용하기
#
# - 파일 쓰기 기능을 이용하여
#   로또 번호 중복없는 6개의 번호가 차례로 구성된
#   결과를 10가지로 추천하여
#   "로또추천.txt" 라는 파일로 남겨라.

# %%
import random as ran

f = open("/home/khs/data/로또 10세트.txt", 'w')

for i in range(10):
    box =[] 
    while len(box) < 6:
        rr = ran.randint(1, 46)
        if rr not in box:
            box.append(rr)

    box_sorted = sorted(box)
    
    print(f"{i+1}번째 결과: {box_sorted}")

    f.write(f"{i+1}번째 결과: {box_sorted}\n")

f.close()
# Out:
# 1번째 결과: [3, 12, 15, 16, 27, 31]
# 2번째 결과: [5, 7, 26, 27, 29, 31]
# 3번째 결과: [6, 15, 20, 29, 33, 35]
# 4번째 결과: [12, 16, 21, 29, 44, 45]
# 5번째 결과: [19, 20, 21, 24, 30, 39]
# 6번째 결과: [8, 17, 19, 20, 40, 41]
# 7번째 결과: [3, 5, 34, 39, 43, 44]
# 8번째 결과: [10, 26, 27, 36, 39, 45]
# 9번째 결과: [10, 11, 13, 20, 39, 44]
# 10번째 결과: [7, 12, 15, 19, 33, 44]

# %%
import time as tt

f = open("./즐겨찾기 종목.txt","r")

while 1:
    line = f.readline()
    if not line: break
    print(line, end="")
    tt.sleep(1)

f.close()
# Out:
# 종목:삼성전자
# 가격:178,400
# 종목:기아
# 가격:164,700
# 종목:현대차
# 가격:504,000
# 종목:한화에어로스페이스
# 가격:1,127,000
# 종목:셀트리온
# 가격:238,500

# %%
import time as tt

f = open("./즐겨찾기 종목.txt","r")

while 1:
    line = f.readline().strip() # strip() 공백문자(\n같은 문자들) 제거 
    if not line: break
    print(line, end="\r")
    tt.sleep(1)
    print(" " * 15, end="\r")

f.close()

# %%
f = open("./즐겨찾기 종목.txt","r")
print(f.readlines())

f.close()
# Out:
# ['종목:삼성전자\n', '가격:178,400\n', '종목:기아\n', '가격:164,700\n', '종목:현대차\n', '가격:504,000\n', '종목:한화에어로스페이스\n', '가격:1,127,000\n', '종목:셀트리온\n', '가격:238,500\n']

# %%
f = open("./즐겨찾기 종목.txt", "r")
print(f.read())

f.close()
# Out:
# 종목:삼성전자
# 가격:178,400
# 종목:기아
# 가격:164,700
# 종목:현대차
# 가격:504,000
# 종목:한화에어로스페이스
# 가격:1,127,000
# 종목:셀트리온
# 가격:238,500

# %%
f = open("./즐겨찾기 종목.txt", "r")

for line in f:
    print(line, end="")

f.close()
# Out:
# 종목:삼성전자
# 가격:178,400
# 종목:기아
# 가격:164,700
# 종목:현대차
# 가격:504,000
# 종목:한화에어로스페이스
# 가격:1,127,000
# 종목:셀트리온
# 가격:238,500

# %%
f = open("./즐겨찾기 종목.txt", "r")

print(f)

f.close()
# Out:
# <_io.TextIOWrapper name='./즐겨찾기 종목.txt' mode='r' encoding='UTF-8'>

# %%
f = open("./즐겨찾기 종목.txt", "r")

f.write(f'종목:홍길동\n가격:9,999,999')

f.close()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[72], line 3
#       1 f = open("./즐겨찾기 종목.txt", "r")
# ----> 3 f.write(f'종목:홍길동\n가격:9,999,999')
#       5 f.close()
#
# UnsupportedOperation: not writable
